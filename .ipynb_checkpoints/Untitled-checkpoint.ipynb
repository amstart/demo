# %%
import datetime

from django.utils import timezone
from demoslogic.premises.models import Premise
from demoslogic.users.models import User
User.objects.all()
newuser = User.objects.create_user(username = 'Alfonsss', email = 'al@fons.com', password = 'top-secretary')
new_premise = Premise.objects.create(user = newuser)
new_premise.save()
time = timezone.now() - datetime.timedelta(days = 30)
old_premise  =  Premise.objects.create(user = newuser, pub_date = time)
setattr(old_premise, 'pub_date', time)
old_premise.save()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# C:\Tools\Anaconda\envs\demoslogic\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      63             else:
# ---> 64                 return self.cursor.execute(sql, params)
#      65
#
# IntegrityError: duplicate key value violates unique constraint "premises_premise_pkey"
# DETAIL:  Key (id)=(20) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-9-0fc7c6bfc030> in <module>()
#       9 new_premise.save()
#      10 time = timezone.now() - datetime.timedelta(days = 30)
# ---> 11 old_premise  =  Premise.objects.create(user = newuser, pub_date = time)
#      12 setattr(old_premise, 'pub_date', time)
#      13 old_premise.save()
#
# ...
